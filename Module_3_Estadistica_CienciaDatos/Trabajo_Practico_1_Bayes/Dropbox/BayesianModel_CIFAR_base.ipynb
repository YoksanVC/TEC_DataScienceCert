# %%
import torch
import torchvision
from PIL import Image
import torchvision.transforms.functional as TF
import matplotlib.pyplot as plt
import torchvision.datasets as datasets
import torchvision.transforms as transformst

# %%
def load_cifar10_dataset(is_train = True):
  # Define a transformation to convert images to grayscale
  transforms_1 = transforms.Compose([
      transforms.ToTensor(),
      transforms.Grayscale(num_output_channels=1)  # Convert to grayscale
  ])
  cifar_trainset = datasets.CIFAR10(root='./data', train = is_train, download = True, transform = transforms_1)
  

  # Initialize an empty list to store batches
  all_data = []
  train_loader = torch.utils.data.DataLoader(cifar_trainset, batch_size = 64, shuffle=True)
  # Iterate over the train_loader to fetch all batches
  for batch in train_loader:
      images, _ = batch  # Extract images from the batch
      all_data.append(images)

  # Concatenate all batches into a single tensor along the batch dimension
  cifar_trainset_tensor = torch.round(torch.cat(all_data, dim=0) * 255)
  cifar_labels = torch.tensor(cifar_trainset.targets)
  print("cifar_trainset_tensor shape ", cifar_trainset_tensor.shape)
  print("cifar_labels ", cifar_labels.shape)
  return (cifar_trainset_tensor, cifar_labels)

load_cifar10_dataset()
# Out:
# path  mnist_dataset/train\0\img_108.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_110.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_111.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_114.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_129.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_141.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_146.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_149.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_153.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_157.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_17.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_183.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_188.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_193.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_195.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_196.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_200.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_201.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_203.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_204.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_23.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_248.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_251.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_260.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_264.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_267.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_272.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_273.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_276.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_279.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_285.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_286.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_288.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_292.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_322.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_327.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_344.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_357.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_366.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_373.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_375.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_4.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_403.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_404.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_412.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_418.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_433.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_435.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_472.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_486.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_5.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_502.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_508.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_538.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_54.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_542.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_63.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_69.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\0\img_98.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_0.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_118.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_12.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_124.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_134.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_140.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_15.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_152.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_182.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_185.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_191.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_2.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_209.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_221.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_224.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_249.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_255.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_256.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_257.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_281.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_295.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_335.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_342.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_35.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_37.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_371.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_38.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_380.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_388.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_400.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_401.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_41.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_424.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_426.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_451.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_468.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_476.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_480.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_484.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_491.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_495.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_497.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_52.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_522.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_527.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_529.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_540.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_544.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_549.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_584.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_59.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_590.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_594.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_598.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_60.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_61.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_68.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_77.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_79.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\1\img_96.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_101.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_104.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_112.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_16.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_169.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_178.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_190.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_199.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_207.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_22.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_233.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_235.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_236.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_239.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_24.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_241.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_247.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_261.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_263.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_271.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_275.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_278.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_287.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_294.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_298.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_302.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_306.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_312.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_324.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_34.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_341.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_348.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_353.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_354.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_355.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_360.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_361.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_365.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_370.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_383.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_397.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_410.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_413.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_432.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_438.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_44.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_444.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_459.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_462.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_463.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_465.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_473.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_474.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_477.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_55.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_56.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_73.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_84.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_94.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\2\img_97.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_13.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_137.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_139.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_14.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_142.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_150.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_155.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_166.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_181.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_192.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_198.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_212.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_219.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_225.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_228.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_230.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_232.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_234.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_240.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_25.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_253.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_284.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_311.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_314.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_316.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_320.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_333.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_334.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_36.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_363.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_379.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_387.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_392.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_394.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_417.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_431.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_458.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_46.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_470.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_481.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_489.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_492.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_510.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_537.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_560.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_565.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_568.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_57.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_581.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_596.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_597.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_606.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_610.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_615.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_619.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_65.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_7.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_70.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_9.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\3\img_90.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\4\img_115.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\4\img_122.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\4\img_130.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\4\img_143.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\4\img_145.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\4\img_148.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\4\img_163.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\4\img_168.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\4\img_170.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\4\img_184.jpg
# x_tensor_bin
# torch.Size([28, 28])
# x_tensor_bin_plain
# torch.Size([784, 1])
# path  mnist_dataset/train\4\img